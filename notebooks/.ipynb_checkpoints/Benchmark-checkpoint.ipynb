# %% [markdown]
# # Benchmark of various outlier detection models
#
# ### The models are evaluated by ROC, Precision @ n and execution time on 17 benchmark datasets. All datasets are split (60% for training and 40% for testing). The full result by averaging 10 indepent trials can be found [here](https://pyod.readthedocs.io/en/latest/benchmark.html).
#
# **[PyOD](https://github.com/yzhao062/pyod)** is a comprehensive **Python toolkit** to **identify outlying objects** in
# multivariate data with both unsupervised and supervised approaches.
# The model covered in this example includes:
#
#   1. Linear Models for Outlier Detection:
#      1. **PCA: Principal Component Analysis** use the sum of
#        weighted projected distances to the eigenvector hyperplane
#        as the outlier outlier scores)
#      2. **MCD: Minimum Covariance Determinant** (use the mahalanobis distances
#        as the outlier scores)
#      3. **OCSVM: One-Class Support Vector Machines**
#
#   2. Proximity-Based Outlier Detection Models:
#      1. **LOF: Local Outlier Factor**
#      2. **CBLOF: Clustering-Based Local Outlier Factor**
#      3. **kNN: k Nearest Neighbors** (use the distance to the kth nearest
#      neighbor as the outlier score)
#      4. **HBOS: Histogram-based Outlier Score**
#
#   3. Probabilistic Models for Outlier Detection:
#      1. **ABOD: Angle-Based Outlier Detection**
#
#   4. Outlier Ensembles and Combination Frameworks
#      1. **Isolation Forest**
#      2. **Feature Bagging**
#
#
# Corresponding file could be found at /examples/compare_all_models.py

# %%
from __future__ import division
from __future__ import print_function

import os
import sys
from time import time

# temporary solution for relative imports in case pyod is not installed
# if pyod is installed, no need to use the following line
sys.path.append(
    os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))
# supress warnings for clean output
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.io import loadmat

from pyod.models.abod import ABOD
from pyod.models.cblof import CBLOF
from pyod.models.feature_bagging import FeatureBagging
from pyod.models.hbos import HBOS
from pyod.models.iforest import IForest
from pyod.models.knn import KNN
from pyod.models.lof import LOF
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.pca import PCA

from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
# Define data file and read X and y
mat_file_list = ['arrhythmia.mat',
                 'cardio.mat',
                 'glass.mat',
                 'ionosphere.mat',
                 'letter.mat',
                 'lympho.mat',
                 'mnist.mat',
                 'musk.mat',
                 'optdigits.mat',
                 'pendigits.mat',
                 'pima.mat',
                 'satellite.mat',
                 'satimage-2.mat',
                 'shuttle.mat',
                 'vertebral.mat',
                 'vowels.mat',
                 'wbc.mat']

# Define nine outlier detection tools to be compared
random_state = np.random.RandomState(42)

df_columns = ['Data', '#Samples', '# Dimensions', 'Outlier Perc',
              'ABOD', 'CBLOF', 'FB', 'HBOS', 'IForest', 'KNN', 'LOF', 'MCD',
              'OCSVM', 'PCA']
roc_df = pd.DataFrame(columns=df_columns)
prn_df = pd.DataFrame(columns=df_columns)
time_df = pd.DataFrame(columns=df_columns)


for mat_file in mat_file_list:
    print("\n... Processing", mat_file, '...')
    mat = loadmat(os.path.join('data', mat_file))

    X = mat['X']
    y = mat['y'].ravel()
    outliers_fraction = np.count_nonzero(y) / len(y)
    outliers_percentage = round(outliers_fraction * 100, ndigits=4)

    # construct containers for saving results
    roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]

    # 60% data for training and 40% for testing
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                        random_state=random_state)

    # standardizing data for processing
    X_train_norm, X_test_norm = standardizer(X_train, X_test)

    classifiers = {'Angle-based Outlier Detector (ABOD)': ABOD(
        contamination=outliers_fraction),
        'Cluster-based Local Outlier Factor': CBLOF(
            contamination=outliers_fraction, check_estimator=False,
            random_state=random_state),
        'Feature Bagging': FeatureBagging(contamination=outliers_fraction,
                                          random_state=random_state),
        'Histogram-base Outlier Detection (HBOS)': HBOS(
            contamination=outliers_fraction),
        'Isolation Forest': IForest(contamination=outliers_fraction,
                                    random_state=random_state),
        'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
        'Local Outlier Factor (LOF)': LOF(
            contamination=outliers_fraction),
        'Minimum Covariance Determinant (MCD)': MCD(
            contamination=outliers_fraction, random_state=random_state),
        'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction),
        'Principal Component Analysis (PCA)': PCA(
            contamination=outliers_fraction, random_state=random_state),
    }

    for clf_name, clf in classifiers.items():
        t0 = time()
        clf.fit(X_train_norm)
        test_scores = clf.decision_function(X_test_norm)
        t1 = time()
        duration = round(t1 - t0, ndigits=4)
        time_list.append(duration)

        roc = round(roc_auc_score(y_test, test_scores), ndigits=4)
        prn = round(precision_n_scores(y_test, test_scores), ndigits=4)

        print('{clf_name} ROC:{roc}, precision @ rank n:{prn}, '
              'execution time: {duration}s'.format(
            clf_name=clf_name, roc=roc, prn=prn, duration=duration))

        roc_list.append(roc)
        prn_list.append(prn)

    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns = df_columns
    time_df = pd.concat([time_df, temp_df], axis=0)

    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns = df_columns
    roc_df = pd.concat([roc_df, temp_df], axis=0)

    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns = df_columns
    prn_df = pd.concat([prn_df, temp_df], axis=0)
# Out:
# ... Processing arrhythmia.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7687, precision @ rank n:0.3571, execution time: 0.9531s
# Cluster-based Local Outlier Factor ROC:0.7789, precision @ rank n:0.4643, execution time: 0.9651s
# Feature Bagging ROC:0.7796, precision @ rank n:0.4643, execution time: 0.0463s
# Histogram-base Outlier Detection (HBOS) ROC:0.8511, precision @ rank n:0.5714, execution time: 0.9175s
# Isolation Forest ROC:0.8595, precision @ rank n:0.5714, execution time: 0.2342s
# K Nearest Neighbors (KNN) ROC:0.782, precision @ rank n:0.5, execution time: 0.027s
# Local Outlier Factor (LOF) ROC:0.7787, precision @ rank n:0.4643, execution time: 0.0052s
# Minimum Covariance Determinant (MCD) ROC:0.8228, precision @ rank n:0.4286, execution time: 0.4275s
# One-class SVM (OCSVM) ROC:0.7986, precision @ rank n:0.5, execution time: 0.0186s
# Principal Component Analysis (PCA) ROC:0.7997, precision @ rank n:0.5, execution time: 0.0409s
#
# ... Processing cardio.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5892, precision @ rank n:0.1918, execution time: 0.2444s
# Cluster-based Local Outlier Factor ROC:0.8845, precision @ rank n:0.4932, execution time: 0.1055s
# Feature Bagging ROC:0.6385, precision @ rank n:0.1781, execution time: 0.4418s
# Histogram-base Outlier Detection (HBOS) ROC:0.8373, precision @ rank n:0.4521, execution time: 0.004s
# Isolation Forest ROC:0.9527, precision @ rank n:0.6027, execution time: 0.2476s
# K Nearest Neighbors (KNN) ROC:0.734, precision @ rank n:0.3562, execution time: 0.0717s
# Local Outlier Factor (LOF) ROC:0.588, precision @ rank n:0.1507, execution time: 0.0431s
# Minimum Covariance Determinant (MCD) ROC:0.8432, precision @ rank n:0.5205, execution time: 0.3188s
# One-class SVM (OCSVM) ROC:0.9478, precision @ rank n:0.5342, execution time: 0.1376s
# Principal Component Analysis (PCA) ROC:0.9616, precision @ rank n:0.6849, execution time: 0.006s
#
# ... Processing glass.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6951, precision @ rank n:0.25, execution time: 0.0237s
# Cluster-based Local Outlier Factor ROC:0.811, precision @ rank n:0.25, execution time: 0.0433s
# Feature Bagging ROC:0.7073, precision @ rank n:0.25, execution time: 0.0271s
# Histogram-base Outlier Detection (HBOS) ROC:0.7073, precision @ rank n:0.0, execution time: 0.002s
# Isolation Forest ROC:0.7134, precision @ rank n:0.25, execution time: 0.1718s
# K Nearest Neighbors (KNN) ROC:0.8384, precision @ rank n:0.25, execution time: 0.005s
# Local Outlier Factor (LOF) ROC:0.7043, precision @ rank n:0.25, execution time: 0.003s
# Minimum Covariance Determinant (MCD) ROC:0.8293, precision @ rank n:0.0, execution time: 0.0215s
# One-class SVM (OCSVM) ROC:0.6585, precision @ rank n:0.25, execution time: 0.002s
# Principal Component Analysis (PCA) ROC:0.686, precision @ rank n:0.25, execution time: 0.001s
#
# ... Processing ionosphere.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9181, precision @ rank n:0.8431, execution time: 0.0381s
# Cluster-based Local Outlier Factor ROC:0.9176, precision @ rank n:0.8039, execution time: 0.0447s
# Feature Bagging ROC:0.9303, precision @ rank n:0.8039, execution time: 0.0307s
# Histogram-base Outlier Detection (HBOS) ROC:0.6052, precision @ rank n:0.3922, execution time: 0.005s
# Isolation Forest ROC:0.8516, precision @ rank n:0.6078, execution time: 0.2046s
# K Nearest Neighbors (KNN) ROC:0.932, precision @ rank n:0.8824, execution time: 0.006s
# Local Outlier Factor (LOF) ROC:0.9227, precision @ rank n:0.7843, execution time: 0.003s
# Minimum Covariance Determinant (MCD) ROC:0.9669, precision @ rank n:0.8627, execution time: 0.0342s
# One-class SVM (OCSVM) ROC:0.8257, precision @ rank n:0.6863, execution time: 0.004s
# Principal Component Analysis (PCA) ROC:0.7941, precision @ rank n:0.5686, execution time: 0.003s
#
# ... Processing letter.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8783, precision @ rank n:0.4375, execution time: 0.2049s
# Cluster-based Local Outlier Factor ROC:0.7783, precision @ rank n:0.1875, execution time: 0.0911s
# Feature Bagging ROC:0.8947, precision @ rank n:0.4062, execution time: 0.3199s
# Histogram-base Outlier Detection (HBOS) ROC:0.6063, precision @ rank n:0.0938, execution time: 0.0065s
# Isolation Forest ROC:0.6178, precision @ rank n:0.0625, execution time: 0.248s
# K Nearest Neighbors (KNN) ROC:0.8573, precision @ rank n:0.3125, execution time: 0.057s
# Local Outlier Factor (LOF) ROC:0.8765, precision @ rank n:0.3438, execution time: 0.0298s
# Minimum Covariance Determinant (MCD) ROC:0.8061, precision @ rank n:0.1875, execution time: 0.5579s
# One-class SVM (OCSVM) ROC:0.5927, precision @ rank n:0.125, execution time: 0.0905s
# Principal Component Analysis (PCA) ROC:0.5216, precision @ rank n:0.125, execution time: 0.015s
#
# ... Processing lympho.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9831, precision @ rank n:0.0, execution time: 0.013s
# Cluster-based Local Outlier Factor ROC:1.0, precision @ rank n:1.0, execution time: 0.0399s
# Feature Bagging ROC:1.0, precision @ rank n:1.0, execution time: 0.0241s
# Histogram-base Outlier Detection (HBOS) ROC:1.0, precision @ rank n:1.0, execution time: 0.004s
# Isolation Forest ROC:1.0, precision @ rank n:1.0, execution time: 0.1745s
# K Nearest Neighbors (KNN) ROC:1.0, precision @ rank n:1.0, execution time: 0.004s
# Local Outlier Factor (LOF) ROC:1.0, precision @ rank n:1.0, execution time: 0.003s
# Minimum Covariance Determinant (MCD) ROC:1.0, precision @ rank n:1.0, execution time: 0.0204s
# One-class SVM (OCSVM) ROC:1.0, precision @ rank n:1.0, execution time: 0.002s
# Principal Component Analysis (PCA) ROC:1.0, precision @ rank n:1.0, execution time: 0.0014s
#
# ... Processing mnist.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7628, precision @ rank n:0.3367, execution time: 2.4245s
# Cluster-based Local Outlier Factor ROC:0.8389, precision @ rank n:0.3912, execution time: 0.2521s
# Feature Bagging ROC:0.7157, precision @ rank n:0.3741, execution time: 6.718s
# Histogram-base Outlier Detection (HBOS) ROC:0.5766, precision @ rank n:0.1361, execution time: 0.0284s
# Isolation Forest ROC:0.7804, precision @ rank n:0.2823, execution time: 1.0983s
# K Nearest Neighbors (KNN) ROC:0.8498, precision @ rank n:0.432, execution time: 1.7678s
# Local Outlier Factor (LOF) ROC:0.7195, precision @ rank n:0.3673, execution time: 0.6801s
# Minimum Covariance Determinant (MCD) ROC:0.8713, precision @ rank n:0.2653, execution time: 1.4953s
# One-class SVM (OCSVM) ROC:0.854, precision @ rank n:0.3946, execution time: 2.5253s
# Principal Component Analysis (PCA) ROC:0.8534, precision @ rank n:0.3878, execution time: 0.0957s
#
# ... Processing musk.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.2161, precision @ rank n:0.1, execution time: 0.7749s
# Cluster-based Local Outlier Factor ROC:1.0, precision @ rank n:1.0, execution time: 0.1111s
# Feature Bagging ROC:0.473, precision @ rank n:0.125, execution time: 1.0929s
# Histogram-base Outlier Detection (HBOS) ROC:0.9999, precision @ rank n:0.975, execution time: 0.0364s
# Isolation Forest ROC:1.0, precision @ rank n:1.0, execution time: 0.6991s
# K Nearest Neighbors (KNN) ROC:0.8009, precision @ rank n:0.175, execution time: 0.4674s
# Local Outlier Factor (LOF) ROC:0.4629, precision @ rank n:0.125, execution time: 0.1083s
# Minimum Covariance Determinant (MCD) ROC:1.0, precision @ rank n:1.0, execution time: 5.871s
# One-class SVM (OCSVM) ROC:1.0, precision @ rank n:1.0, execution time: 4.1421s
# Principal Component Analysis (PCA) ROC:1.0, precision @ rank n:1.0, execution time: 0.1012s
#
# ... Processing optdigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.4894, precision @ rank n:0.0152, execution time: 1.0626s
# Cluster-based Local Outlier Factor ROC:0.7901, precision @ rank n:0.0, execution time: 0.161s
# Feature Bagging ROC:0.5062, precision @ rank n:0.0303, execution time: 3.0739s
# Histogram-base Outlier Detection (HBOS) ROC:0.8774, precision @ rank n:0.2121, execution time: 0.0226s
# Isolation Forest ROC:0.6682, precision @ rank n:0.0, execution time: 0.534s
# K Nearest Neighbors (KNN) ROC:0.406, precision @ rank n:0.0, execution time: 0.5536s
# Local Outlier Factor (LOF) ROC:0.5277, precision @ rank n:0.0303, execution time: 0.3146s
# Minimum Covariance Determinant (MCD) ROC:0.3822, precision @ rank n:0.0, execution time: 0.771s
# One-class SVM (OCSVM) ROC:0.5171, precision @ rank n:0.0, execution time: 1.0266s
# Principal Component Analysis (PCA) ROC:0.526, precision @ rank n:0.0, execution time: 0.0297s
#
# ... Processing pendigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.667, precision @ rank n:0.0526, execution time: 0.9744s
# Cluster-based Local Outlier Factor ROC:0.8082, precision @ rank n:0.1579, execution time: 0.1314s
# Feature Bagging ROC:0.4889, precision @ rank n:0.0526, execution time: 2.0341s
# Histogram-base Outlier Detection (HBOS) ROC:0.9348, precision @ rank n:0.2632, execution time: 0.0051s
# Isolation Forest ROC:0.9414, precision @ rank n:0.2807, execution time: 0.3971s
# K Nearest Neighbors (KNN) ROC:0.7371, precision @ rank n:0.0702, execution time: 0.5207s
# Local Outlier Factor (LOF) ROC:0.4965, precision @ rank n:0.0702, execution time: 0.5402s
# Minimum Covariance Determinant (MCD) ROC:0.8204, precision @ rank n:0.0877, execution time: 1.1747s
# One-class SVM (OCSVM) ROC:0.9235, precision @ rank n:0.3158, execution time: 1.4865s
# Principal Component Analysis (PCA) ROC:0.9309, precision @ rank n:0.3158, execution time: 0.0053s
#
# ... Processing pima.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7163, precision @ rank n:0.5253, execution time: 0.0931s
# Cluster-based Local Outlier Factor ROC:0.67, precision @ rank n:0.4949, execution time: 0.0719s
# Feature Bagging ROC:0.6448, precision @ rank n:0.4444, execution time: 0.0826s
# Histogram-base Outlier Detection (HBOS) ROC:0.711, precision @ rank n:0.5354, execution time: 0.002s
# Isolation Forest ROC:0.6872, precision @ rank n:0.5253, execution time: 0.1776s
# K Nearest Neighbors (KNN) ROC:0.7395, precision @ rank n:0.5859, execution time: 0.0175s
# Local Outlier Factor (LOF) ROC:0.6574, precision @ rank n:0.4646, execution time: 0.006s
# Minimum Covariance Determinant (MCD) ROC:0.7175, precision @ rank n:0.5152, execution time: 0.025s
# One-class SVM (OCSVM) ROC:0.6561, precision @ rank n:0.5051, execution time: 0.023s
# Principal Component Analysis (PCA) ROC:0.6762, precision @ rank n:0.5354, execution time: 0.001s
#
# ... Processing satellite.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5653, precision @ rank n:0.3962, execution time: 0.9931s
# Cluster-based Local Outlier Factor ROC:0.7241, precision @ rank n:0.5412, execution time: 0.1768s
# Feature Bagging ROC:0.572, precision @ rank n:0.4, execution time: 4.4136s
# Histogram-base Outlier Detection (HBOS) ROC:0.7486, precision @ rank n:0.57, execution time: 0.0141s
# Isolation Forest ROC:0.6827, precision @ rank n:0.5688, execution time: 0.4621s
# K Nearest Neighbors (KNN) ROC:0.6853, precision @ rank n:0.4988, execution time: 0.5107s
# Local Outlier Factor (LOF) ROC:0.572, precision @ rank n:0.395, execution time: 0.442s
# Minimum Covariance Determinant (MCD) ROC:0.8055, precision @ rank n:0.6762, execution time: 1.2039s
# One-class SVM (OCSVM) ROC:0.6478, precision @ rank n:0.5225, execution time: 1.4049s
# Principal Component Analysis (PCA) ROC:0.5923, precision @ rank n:0.465, execution time: 0.0165s
#
# ... Processing satimage-2.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8432, precision @ rank n:0.2333, execution time: 0.9027s
# Cluster-based Local Outlier Factor ROC:0.9998, precision @ rank n:0.9333, execution time: 0.1556s
# Feature Bagging ROC:0.5235, precision @ rank n:0.1667, execution time: 3.8686s
# Histogram-base Outlier Detection (HBOS) ROC:0.9784, precision @ rank n:0.6, execution time: 0.0134s
# Isolation Forest ROC:0.9947, precision @ rank n:0.8333, execution time: 0.4363s
# K Nearest Neighbors (KNN) ROC:0.9515, precision @ rank n:0.4333, execution time: 0.4722s
# Local Outlier Factor (LOF) ROC:0.5257, precision @ rank n:0.1667, execution time: 0.3763s
# Minimum Covariance Determinant (MCD) ROC:0.9963, precision @ rank n:0.6667, execution time: 1.0709s
# One-class SVM (OCSVM) ROC:0.9997, precision @ rank n:0.9, execution time: 1.1953s
# Principal Component Analysis (PCA) ROC:0.9816, precision @ rank n:0.7333, execution time: 0.0235s
#
# ... Processing shuttle.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6173, precision @ rank n:0.2003, execution time: 7.6895s
# Cluster-based Local Outlier Factor ROC:0.6273, precision @ rank n:0.2025, execution time: 0.2809s

# %%
print('Time complexity')
time_df

# %% [markdown]
# Analyze the performance of ROC and Precision @ n

# %%
print('ROC Performance')
roc_df

# %%
print('Precision @ n Performance')
prn_df
